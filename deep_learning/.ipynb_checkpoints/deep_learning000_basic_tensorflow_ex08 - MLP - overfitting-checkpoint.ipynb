# %% [markdown]
# Validation set and how it helps the problem of overfitting.
#
# What is overfitting?
# This is when you create a model that performs very well on your training data (hooray!). But is performs pretty bad on your test data (sad face). The good news is that there are options to deal with this issue.
#
# - Training set - This is the data you will be training your model with.
#
# - Test set - This is the data you will be testing your model with. The test set should not contain data that is in the training set.
#
# A Validation set
# - an estimation of the Test set
# - does not contain data from the Training or test set
# - use during training. Typically what we do is for every N iterations (epochs), we "test" our model using the Validation set to see how our model is doing while training and before we run our model through our test data
# - If the Validation set says we are 95% accurate, then we can say that when we try our model on the Test set, we should get something close to 95% accuracy also
#
#
# Advantages of using a Validation set
# - can determine if overfitting is a problem
# - during training, training error goes down but validation error goes up, sign of overfitting
#
# Deal with overfitting
# As soon as you realize you are starting to overfit, simply stop training. This is called early stopping and it works great at preventing your model from overfitting.

# %%
# import libraries
import tensorflow as tf
import pandas as pd
import numpy as np
import sys
import datetime
import matplotlib.pyplot as plt
plt.style.use('ggplot') # use this plot style
# %matplotlib inline

# %%
# Function to model

# y = a * x^4 + b 

# Training - 70%
# Validation - 15%
# Test - 15%



# Let's generate 1000 random samples
pool = np.random.rand(1000,1).astype(np.float32)

# Shuffle the samples
np.random.shuffle(pool)

# sample size of 15%
sample = int(1000 * 0.15)

# 15% test
test_x = pool[0:sample]

# 15% validation
valid_x = pool[sample:sample*2]

# 70% training
train_x = pool[sample*2:]

print('Testing data points: ' + str(test_x.shape))
print('Validation data points: ' + str(valid_x.shape))
print('Training data points: ' + str(train_x.shape))

# Let's compute the ouput using 2 for a, 5 for b
test_y = 2.0 * test_x**4 + 5
valid_y = 2.0 * valid_x**4 + 5
train_y = 2.0 * train_x**4 + 5

df = pd.DataFrame({'x':train_x[:,0],
                   'y':train_y[:,0]})
df.head()

df.describe()

df.plot.scatter(x='x', y='y', figsize=(15,5));
# Out:
# Testing data points: (150, 1)
# Validation data points: (150, 1)
# Training data points: (700, 1)

# %%
print(train_x.shape[1])
print(train_y.shape[1])
# Out:
# 1
# 1

# %%
def add_layer(inputs, in_size, out_size, activation_function=None):
    
    # tf.random_normal([what is the size of your batches, size of output layer])
    Weights = tf.Variable(tf.truncated_normal([in_size, out_size], mean=0.1, stddev=0.1))
    
    # tf.random_normal([size of output layer])
    biases = tf.Variable(tf.truncated_normal([out_size], mean=0.1, stddev=0.1))
    
    # shape of pred = [size of your batches, size of output layer]
    pred = tf.matmul(inputs, Weights) + biases

    if activation_function is None:
        outputs = pred
    else:
        outputs = activation_function(pred)
    return outputs

# %%
epoch = 10000

# hidden layer neuron no or nodes
hs = [50, 100]
for hidden_size in hs:

    # placeholders
    # shape=[how many samples do you have, how many input neurons]
    x = tf.placeholder(tf.float32, shape=[None, train_x.shape[1]], name="01_x")
    y = tf.placeholder(tf.float32, shape=[None, train_y.shape[1]], name="01_y")

    print("shape of x and y:")
    print(x.get_shape(),y.get_shape())

    print("Hidden layer neuron: ", hidden_size)

    # create your hidden layers!
    h1 = add_layer(x, 1, hidden_size, tf.nn.relu)
    h2 = add_layer(h1, hidden_size, hidden_size, tf.nn.relu)

    print("shape of hidden layers:")
    print(h1.get_shape(), h2.get_shape())

    # Output Layers
    pred = add_layer(h2, hidden_size, 1)

    print("shape of output layer:")
    print(pred.get_shape())

    # minimize the mean squared errors.
    loss = tf.reduce_mean(tf.square(pred - y))

    # pick optimizer
    optimizer = tf.train.GradientDescentOptimizer(0.001)
    train = optimizer.minimize(loss)

    # check accuracy of model
    correct_prediction = tf.equal(tf.round(pred), tf.round(y))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
    
    
    # Best validation accuracy seen so far.
    best_valid_acc = 0.0

    # Iteration-number for last improvement to validation accuracy.
    last_improvement = 0

    # Stop optimization if no improvement found in this many iterations.
    require_improvement = 2000
    
    # initialize the variables
    init = tf.global_variables_initializer()

    # hold step and error values
    t = []

    # Run your graph
    with tf.Session() as sess:
        print("Session ready to run...")
        # initialize variables
        sess.run(init)

        # Fit the function.
        for step in range(epoch):

            # get your data
            train_data = {x:train_x, y:train_y}
            valid_data = {x:valid_x, y:valid_y}
            test_data = {x:test_x, y:test_y}

            # training in progress...
            train_loss, train_pred = sess.run([loss, train], feed_dict=train_data)        

            # print every n iterations
            if step%100==0:

                # capture the step and error for analysis
                valid_loss = sess.run(loss, feed_dict=valid_data) 
                t.append((step, train_loss, valid_loss))   

                # get snapshot of current training accuracy       
                train_acc = accuracy.eval(train_data)
                valid_acc = accuracy.eval(valid_data) 
                
                # If validation accuracy is an improvement over best-known.
                if valid_acc > best_valid_acc:
                    # Update the best-known validation accuracy.
                    best_valid_acc = valid_acc

                    # Set the iteration for the last improvement to current.
                    last_improvement = step

                    # Flag when ever an improvement is found
                    improved_str = '*'
                else:
                    # An empty string to be printed below.
                    # Shows that no improvement was found.
                    improved_str = ''   

                print("Training loss at step %d: %f %s" % (step, train_loss, improved_str))        
                print("Validation %f" % (valid_loss))            

                # If no improvement found in the required number of iterations.
                if step - last_improvement > require_improvement:
                    print("No improvement found in a while, stopping optimization.")

                    # Break out from the for-loop.
                    break                

        # here is where you see how good of a Data Scientist you are        
        print("Accuracy on the Training Set:", accuracy.eval(train_data) )
        print("Accuracy on the Validation Set:", accuracy.eval(valid_data) )
        print("Accuracy on the Test Set:", accuracy.eval(test_data) )

        # capture predictions on test data 
        test_results = sess.run(pred, feed_dict={x:test_x})  
        df_final = pd.DataFrame({'test_x':test_x[:,0],
                                 'pred':test_results[:,0]})

        # capture training and validation loss
        df_loss = pd.DataFrame(t, columns=['step', 'train_loss', 'valid_loss'])  

    fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(15, 5))

    # Chart 1 - Shows the line we are trying to model
    df.plot.scatter(x='x', y='y', ax=axes, color='red')

    # Chart 2 - Shows the line our trained model came up with
    gLabel = "target vs pred with " + str(hidden_size) + " neuron(s)"
    df_final.plot.scatter(x='test_x', y='pred', ax=axes, alpha=0.3)
    # add a info to plot
    axes.set_title(gLabel, fontsize=20)
    axes.set_ylabel('y', fontsize=15)
    axes.set_xlabel('x', fontsize=15)
    axes.legend(["target", "pred"], loc='best');

    gLabel = "loss with " + str(hidden_size) + " neuron(s)"
    df_loss.set_index('step').plot(logy=True, figsize=(15,5))
    # add a info to plot
    axes.set_title(gLabel, fontsize=20)
# Out:
# shape of x and y:
# (?, 1) (?, 1)
# Hidden layer neuron:  50
# shape of hidden layers:
# (?, 50) (?, 50)
# shape of output layer:
# (?, 1)
# Session ready to run...
# Training loss at step 0: 1.095727 *
# Validation 0.831334
# Training loss at step 100: 0.152086 *
# Validation 0.164248
# Training loss at step 200: 0.114106 *
# Validation 0.124178
# Training loss at step 300: 0.092898 *
# Validation 0.100799
# Training loss at step 400: 0.080999 *
# Validation 0.087056
# Training loss at step 500: 0.073676 *
# Validation 0.078213
# Training loss at step 600: 0.068835 *
# Validation 0.072147
# Training loss at step 700: 0.065532 *
# Validation 0.067851
# Training loss at step 800: 0.063221 *
# Validation 0.064743
# Training loss at step 900: 0.061555 *
# Validation 0.062460
# Training loss at step 1000: 0.060340 *
# Validation 0.060744
# Training loss at step 1100: 0.059448
# Validation 0.059428
# Training loss at step 1200: 0.058776 *
# Validation 0.058402
# Training loss at step 1300: 0.058259
# Validation 0.057596
# Training loss at step 1400: 0.057849
# Validation 0.056950
# Training loss at step 1500: 0.057509
# Validation 0.056413
# Training loss at step 1600: 0.057220
# Validation 0.055961
# Training loss at step 1700: 0.056959 *
# Validation 0.055577
# Training loss at step 1800: 0.056717
# Validation 0.055252
# Training loss at step 1900: 0.056487
# Validation 0.054964
# Training loss at step 2000: 0.056266
# Validation 0.054699
# Training loss at step 2100: 0.056050
# Validation 0.054451
# Training loss at step 2200: 0.055838
# Validation 0.054214
# Training loss at step 2300: 0.055629
# Validation 0.053983
# Training loss at step 2400: 0.055422
# Validation 0.053760
# Training loss at step 2500: 0.055216
# Validation 0.053543
# Training loss at step 2600: 0.055011
# Validation 0.053333
# Training loss at step 2700: 0.054807
# Validation 0.053127
# Training loss at step 2800: 0.054603
# Validation 0.052922
# Training loss at step 2900: 0.054399
# Validation 0.052717
# Training loss at step 3000: 0.054195
# Validation 0.052513
# Training loss at step 3100: 0.053990
# Validation 0.052311
# Training loss at step 3200: 0.053786
# Validation 0.052111
# Training loss at step 3300: 0.053581
# Validation 0.051908
# Training loss at step 3400: 0.053376
# Validation 0.051706
# Training loss at step 3500: 0.053171
# Validation 0.051504
# Training loss at step 3600: 0.052965
# Validation 0.051302
# Training loss at step 3700: 0.052759
# Validation 0.051100
# Training loss at step 3800: 0.052553
# Validation 0.050898
# No improvement found in a while, stopping optimization.
# Accuracy on the Training Set: 0.822857
# Accuracy on the Validation Set: 0.793333
# Accuracy on the Test Set: 0.84
# shape of x and y:
# (?, 1) (?, 1)
# Hidden layer neuron:  100
# shape of hidden layers:
# (?, 100) (?, 100)
# shape of output layer:
# (?, 1)
# Session ready to run...
# Training loss at step 0: 127.936546
# Validation 11.914452
# Training loss at step 100: 0.143301 *
# Validation 0.154620
# Training loss at step 200: 0.105469 *
# Validation 0.114844
# Training loss at step 300: 0.086282 *
# Validation 0.093719
# Training loss at step 400: 0.075316 *
# Validation 0.081077
# Training loss at step 500: 0.068499 *
# Validation 0.072903
# Training loss at step 600: 0.063896 *
# Validation 0.067221
# Training loss at step 700: 0.060590 *
# Validation 0.063049
# Training loss at step 800: 0.058135 *
# Validation 0.059883
# Training loss at step 900: 0.056252
# Validation 0.057431
# Training loss at step 1000: 0.054662
# Validation 0.055410
# Training loss at step 1100: 0.053171 *
# Validation 0.053593
# Training loss at step 1200: 0.051925 *
# Validation 0.052079
# Training loss at step 1300: 0.050944
# Validation 0.050881
# Training loss at step 1400: 0.050139
# Validation 0.049883
# Training loss at step 1500: 0.049452
# Validation 0.049031
# Training loss at step 1600: 0.048850
# Validation 0.048284
# Training loss at step 1700: 0.048317
# Validation 0.047624
# Training loss at step 1800: 0.047832
# Validation 0.047025
# Training loss at step 1900: 0.047383
# Validation 0.046471
# Training loss at step 2000: 0.046958
# Validation 0.045951
# Training loss at step 2100: 0.046552
# Validation 0.045464
# Training loss at step 2200: 0.046158
# Validation 0.045001
# Training loss at step 2300: 0.045772
# Validation 0.044558
# Training loss at step 2400: 0.045392
# Validation 0.044130
# Training loss at step 2500: 0.044992
# Validation 0.043698
# Training loss at step 2600: 0.044426
# Validation 0.043137
# Training loss at step 2700: 0.043681
# Validation 0.042396
# Training loss at step 2800: 0.042988
# Validation 0.041687
# Training loss at step 2900: 0.042435 *
# Validation 0.041126
# Training loss at step 3000: 0.041911
# Validation 0.040602
# Training loss at step 3100: 0.041260
# Validation 0.039960
# Training loss at step 3200: 0.040591
# Validation 0.039293
# Training loss at step 3300: 0.040062
# Validation 0.038763
# Training loss at step 3400: 0.039624
# Validation 0.038320
# Training loss at step 3500: 0.039243
# Validation 0.037925
# Training loss at step 3600: 0.038886
# Validation 0.037559
# Training loss at step 3700: 0.038548
# Validation 0.037210
# Training loss at step 3800: 0.038226
# Validation 0.036873
# Training loss at step 3900: 0.037911
# Validation 0.036545
# Training loss at step 4000: 0.037600
# Validation 0.036225
# Training loss at step 4100: 0.037294
# Validation 0.035913
# Training loss at step 4200: 0.036991
# Validation 0.035607
# Training loss at step 4300: 0.036687
# Validation 0.035301
# Training loss at step 4400: 0.036361
# Validation 0.034979
# Training loss at step 4500: 0.035943
# Validation 0.034589
# Training loss at step 4600: 0.035390
# Validation 0.034065
# Training loss at step 4700: 0.034750
# Validation 0.033447
# Training loss at step 4800: 0.034138
# Validation 0.032837
# Training loss at step 4900: 0.033609
# Validation 0.032301
# Training loss at step 5000: 0.033161 *
# Validation 0.031854
# Training loss at step 5100: 0.032762
# Validation 0.031452
# Training loss at step 5200: 0.032394 *
# Validation 0.031082
# Training loss at step 5300: 0.032054
# Validation 0.030738
# Training loss at step 5400: 0.031729
# Validation 0.030413
# Training loss at step 5500: 0.031412
# Validation 0.030103
# Training loss at step 5600: 0.031104
# Validation 0.029799
# Training loss at step 5700: 0.030803 *
# Validation 0.029503
# Training loss at step 5800: 0.030507
# Validation 0.029210
# Training loss at step 5900: 0.030216
# Validation 0.028922
# Training loss at step 6000: 0.029930
# Validation 0.028637
# Training loss at step 6100: 0.029647
# Validation 0.028354
# Training loss at step 6200: 0.029365
# Validation 0.028075
# Training loss at step 6300: 0.029085 *
# Validation 0.027798
# Training loss at step 6400: 0.028808
# Validation 0.027523
# Training loss at step 6500: 0.028532 *
# Validation 0.027249
# Training loss at step 6600: 0.028257
# Validation 0.026979
# Training loss at step 6700: 0.027984
# Validation 0.026710
# Training loss at step 6800: 0.027713
# Validation 0.026444
# Training loss at step 6900: 0.027443
# Validation 0.026179
# Training loss at step 7000: 0.027174
# Validation 0.025915
# Training loss at step 7100: 0.026907 *
# Validation 0.025652
# Training loss at step 7200: 0.026641
# Validation 0.025391
# Training loss at step 7300: 0.026376
# Validation 0.025132
# Training loss at step 7400: 0.026113
# Validation 0.024874
# Training loss at step 7500: 0.025852
# Validation 0.024617
# Training loss at step 7600: 0.025591
# Validation 0.024361
# Training loss at step 7700: 0.025333
# Validation 0.024105
# Training loss at step 7800: 0.025076
# Validation 0.023851
# Training loss at step 7900: 0.024820
# Validation 0.023599
# Training loss at step 8000: 0.024566
# Validation 0.023350
# Training loss at step 8100: 0.024313
# Validation 0.023102
# Training loss at step 8200: 0.024062
# Validation 0.022856
# Training loss at step 8300: 0.023813
# Validation 0.022611
# Training loss at step 8400: 0.023565
# Validation 0.022368
# Training loss at step 8500: 0.023318
# Validation 0.022126
# Training loss at step 8600: 0.023073 *
# Validation 0.021885
# Training loss at step 8700: 0.022829
# Validation 0.021645
# Training loss at step 8800: 0.022584
# Validation 0.021405
# Training loss at step 8900: 0.022340
# Validation 0.021165
# Training loss at step 9000: 0.022096
# Validation 0.020922
# Training loss at step 9100: 0.021850
# Validation 0.020677
# Training loss at step 9200: 0.021600
# Validation 0.020428
# Training loss at step 9300: 0.021342
# Validation 0.020174
# Training loss at step 9400: 0.021075
# Validation 0.019911
# Training loss at step 9500: 0.020804
# Validation 0.019643
# Training loss at step 9600: 0.020527
# Validation 0.019370
# Training loss at step 9700: 0.020247
# Validation 0.019093
# Training loss at step 9800: 0.019964
# Validation 0.018816
# Training loss at step 9900: 0.019683 *
# Validation 0.018540
# Accuracy on the Training Set: 0.862857
# Accuracy on the Validation Set: 0.873333
# Accuracy on the Test Set: 0.88
