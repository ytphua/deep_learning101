# %%
# https://deeplearningcourses.com/c/deep-learning-convolutional-neural-networks-theano-tensorflow
# https://udemy.com/deep-learning-convolutional-neural-networks-theano-tensorflow
# get the data: http://ufldl.stanford.edu/housenumbers/
from __future__ import print_function, division
from builtins import range
# Note: you may need to update your version of future
# sudo pip install -U future

# %matplotlib inline
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from scipy.io import loadmat
from sklearn.utils import shuffle
from datetime import datetime

# %%
def y2indicator(y):
    N = len(y)
    ind = np.zeros((N, 10))
    for i in range(N):
        ind[i, y[i]] = 1
    return ind


def error_rate(p, t):
    return np.mean(p != t)


def flatten(X):
    # input will be (32, 32, 3, N)
    # output will be (N, 3072)
    N = X.shape[-1]
    flat = np.zeros((N, 3072))
    for i in range(N):
        flat[i] = X[:,:,:,i].reshape(3072)
    return flat

# %%
def get_data():
    if not os.path.exists('cnn_data/train_32x32.mat'):
        print('Looking for cnn_data/train_32x32.mat')
        print('You have not downloaded the data and/or not placed the files in the correct location.')
        print('Please get the data from: http://ufldl.stanford.edu/housenumbers')
        print('Place train_32x32.mat and test_32x32.mat in the folder large_files adjacent to the class folder')
        exit()

    train = loadmat('cnn_data/train_32x32.mat')
    test  = loadmat('cnn_data/test_32x32.mat')
    return train, test

# %%
# load data
train, test = get_data()

Xtrain = flatten(train['X'].astype(np.float32) / 255)
Ytrain = train['y'].flatten() - 1
Xtrain, Ytrain = shuffle(Xtrain, Ytrain)
Ytrain_ind = y2indicator(Ytrain)

Xtest  = flatten(test['X'].astype(np.float32) / 255)
Ytest  = test['y'].flatten() - 1
Ytest_ind = y2indicator(Ytest)

# %%
# gradient descent params
max_iter = 20
print_period = 10
N, D = Xtrain.shape
batch_sz = 500
n_batches = int(N / batch_sz)

# initial weights
M1 = 1000 # hidden layer size
M2 = 500
K = 10
W1_init = np.random.randn(D, M1) / np.sqrt(D + M1)
b1_init = np.zeros(M1)
W2_init = np.random.randn(M1, M2) / np.sqrt(M1 + M2)
b2_init = np.zeros(M2)
W3_init = np.random.randn(M2, K) / np.sqrt(M2 + K)
b3_init = np.zeros(K)

# define variables and expressions
X = tf.placeholder(tf.float32, shape=(None, D), name='X')
T = tf.placeholder(tf.float32, shape=(None, K), name='T')
W1 = tf.Variable(W1_init.astype(np.float32))
b1 = tf.Variable(b1_init.astype(np.float32))
W2 = tf.Variable(W2_init.astype(np.float32))
b2 = tf.Variable(b2_init.astype(np.float32))
W3 = tf.Variable(W3_init.astype(np.float32))
b3 = tf.Variable(b3_init.astype(np.float32))

Z1 = tf.nn.relu( tf.matmul(X, W1) + b1 )
Z2 = tf.nn.relu( tf.matmul(Z1, W2) + b2 )
Yish = tf.matmul(Z2, W3) + b3

cost = tf.reduce_sum(
    tf.nn.softmax_cross_entropy_with_logits(logits=Yish, labels=T)
)

train_op = tf.train.RMSPropOptimizer(0.0001, decay=0.99, momentum=0.9).minimize(cost)

# we'll use this to calculate the error rate
predict_op = tf.argmax(Yish, 1)

t0 = datetime.now()
LL = []
init = tf.global_variables_initializer()
with tf.Session() as session:
    session.run(init)

    for i in range(max_iter):
        for j in range(n_batches):
            Xbatch = Xtrain[j*batch_sz:(j*batch_sz + batch_sz),]
            Ybatch = Ytrain_ind[j*batch_sz:(j*batch_sz + batch_sz),]

            session.run(train_op, feed_dict={X: Xbatch, T: Ybatch})
            if j % print_period == 0:
                test_cost = session.run(cost, feed_dict={X: Xtest, T: Ytest_ind})
                prediction = session.run(predict_op, feed_dict={X: Xtest})
                err = error_rate(prediction, Ytest)
                print("Cost / err at iteration i=%d, j=%d: %.3f / %.3f" % (i, j, test_cost, err))
                LL.append(test_cost)
print("Elapsed time:", (datetime.now() - t0))
plt.plot(LL)
plt.show()
# Out:
# Cost / err at iteration i=0, j=0: 58636.637 / 0.805
# Cost / err at iteration i=0, j=10: 58242.219 / 0.804
# Cost / err at iteration i=0, j=20: 58345.320 / 0.804
# Cost / err at iteration i=0, j=30: 58434.711 / 0.847
# Cost / err at iteration i=0, j=40: 57858.789 / 0.803
# Cost / err at iteration i=0, j=50: 57740.691 / 0.784
# Cost / err at iteration i=0, j=60: 56814.055 / 0.787
# Cost / err at iteration i=0, j=70: 56006.914 / 0.756
# Cost / err at iteration i=0, j=80: 60075.340 / 0.804
# Cost / err at iteration i=0, j=90: 55605.137 / 0.755
# Cost / err at iteration i=0, j=100: 53035.934 / 0.719
# Cost / err at iteration i=0, j=110: 52917.047 / 0.721
# Cost / err at iteration i=0, j=120: 49769.109 / 0.668
# Cost / err at iteration i=0, j=130: 47473.824 / 0.637
# Cost / err at iteration i=0, j=140: 45335.680 / 0.590
# Cost / err at iteration i=1, j=0: 45857.641 / 0.635
# Cost / err at iteration i=1, j=10: 43149.664 / 0.563
# Cost / err at iteration i=1, j=20: 42807.789 / 0.558
# Cost / err at iteration i=1, j=30: 40710.109 / 0.499
# Cost / err at iteration i=1, j=40: 40970.824 / 0.528
# Cost / err at iteration i=1, j=50: 39854.883 / 0.482
# Cost / err at iteration i=1, j=60: 38205.492 / 0.479
# Cost / err at iteration i=1, j=70: 39490.969 / 0.478
# Cost / err at iteration i=1, j=80: 39027.031 / 0.486
# Cost / err at iteration i=1, j=90: 37888.059 / 0.462
# Cost / err at iteration i=1, j=100: 36478.574 / 0.442
# Cost / err at iteration i=1, j=110: 36091.348 / 0.439
# Cost / err at iteration i=1, j=120: 35703.152 / 0.438
# Cost / err at iteration i=1, j=130: 36125.074 / 0.439
# Cost / err at iteration i=1, j=140: 35292.750 / 0.434
# Cost / err at iteration i=2, j=0: 34352.715 / 0.413
# Cost / err at iteration i=2, j=10: 34054.430 / 0.404
# Cost / err at iteration i=2, j=20: 35946.316 / 0.440
# Cost / err at iteration i=2, j=30: 35555.820 / 0.430
# Cost / err at iteration i=2, j=40: 34837.285 / 0.410
# Cost / err at iteration i=2, j=50: 34713.043 / 0.431
# Cost / err at iteration i=2, j=60: 32788.469 / 0.388
# Cost / err at iteration i=2, j=70: 32923.652 / 0.384
# Cost / err at iteration i=2, j=80: 33137.992 / 0.395
# Cost / err at iteration i=2, j=90: 32209.240 / 0.380
# Cost / err at iteration i=2, j=100: 31951.168 / 0.374
# Cost / err at iteration i=2, j=110: 32279.527 / 0.381
# Cost / err at iteration i=2, j=120: 32090.756 / 0.381
# Cost / err at iteration i=2, j=130: 32018.031 / 0.367
# Cost / err at iteration i=2, j=140: 32471.234 / 0.381
# Cost / err at iteration i=3, j=0: 32358.500 / 0.386
# Cost / err at iteration i=3, j=10: 30666.836 / 0.358
# Cost / err at iteration i=3, j=20: 31342.105 / 0.371
# Cost / err at iteration i=3, j=30: 30144.654 / 0.349
# Cost / err at iteration i=3, j=40: 30742.363 / 0.356
# Cost / err at iteration i=3, j=50: 30374.578 / 0.354
# Cost / err at iteration i=3, j=60: 29992.848 / 0.356
# Cost / err at iteration i=3, j=70: 30837.312 / 0.351
# Cost / err at iteration i=3, j=80: 30350.293 / 0.356
# Cost / err at iteration i=3, j=90: 29573.746 / 0.340
# Cost / err at iteration i=3, j=100: 29229.254 / 0.339
# Cost / err at iteration i=3, j=110: 29627.781 / 0.350
# Cost / err at iteration i=3, j=120: 29730.793 / 0.351
# Cost / err at iteration i=3, j=130: 29222.131 / 0.343
# Cost / err at iteration i=3, j=140: 30183.775 / 0.354
# Cost / err at iteration i=4, j=0: 28819.781 / 0.339
# Cost / err at iteration i=4, j=10: 28888.145 / 0.337
# Cost / err at iteration i=4, j=20: 28474.729 / 0.332
# Cost / err at iteration i=4, j=30: 28236.594 / 0.330
# Cost / err at iteration i=4, j=40: 28959.799 / 0.333
# Cost / err at iteration i=4, j=50: 28518.375 / 0.330
# Cost / err at iteration i=4, j=60: 28163.611 / 0.327
# Cost / err at iteration i=4, j=70: 28702.781 / 0.329
# Cost / err at iteration i=4, j=80: 28485.406 / 0.329
# Cost / err at iteration i=4, j=90: 28757.289 / 0.335
# Cost / err at iteration i=4, j=100: 28420.238 / 0.329
# Cost / err at iteration i=4, j=110: 27480.330 / 0.321
# Cost / err at iteration i=4, j=120: 27313.848 / 0.314
# Cost / err at iteration i=4, j=130: 28017.934 / 0.331
# Cost / err at iteration i=4, j=140: 28346.609 / 0.334
# Cost / err at iteration i=5, j=0: 26909.625 / 0.313
# Cost / err at iteration i=5, j=10: 27248.439 / 0.314
# Cost / err at iteration i=5, j=20: 27024.682 / 0.312
# Cost / err at iteration i=5, j=30: 26842.914 / 0.314
# Cost / err at iteration i=5, j=40: 28016.676 / 0.329
# Cost / err at iteration i=5, j=50: 26257.027 / 0.301
# Cost / err at iteration i=5, j=60: 26595.398 / 0.301
# Cost / err at iteration i=5, j=70: 27114.855 / 0.309
# Cost / err at iteration i=5, j=80: 26449.227 / 0.302
# Cost / err at iteration i=5, j=90: 27178.332 / 0.320
# Cost / err at iteration i=5, j=100: 26891.916 / 0.313
# Cost / err at iteration i=5, j=110: 26454.732 / 0.308
# Cost / err at iteration i=5, j=120: 26486.984 / 0.303
# Cost / err at iteration i=5, j=130: 25054.516 / 0.285
# Cost / err at iteration i=5, j=140: 26074.240 / 0.300
# Cost / err at iteration i=6, j=0: 25264.562 / 0.291
# Cost / err at iteration i=6, j=10: 25735.850 / 0.295
# Cost / err at iteration i=6, j=20: 25713.133 / 0.296
# Cost / err at iteration i=6, j=30: 25805.543 / 0.300
# Cost / err at iteration i=6, j=40: 27088.938 / 0.308
# Cost / err at iteration i=6, j=50: 25071.613 / 0.288
# Cost / err at iteration i=6, j=60: 24899.043 / 0.284
# Cost / err at iteration i=6, j=70: 26033.008 / 0.296
# Cost / err at iteration i=6, j=80: 26613.871 / 0.304
# Cost / err at iteration i=6, j=90: 25564.924 / 0.293
# Cost / err at iteration i=6, j=100: 25588.691 / 0.296
# Cost / err at iteration i=6, j=110: 25647.484 / 0.297
# Cost / err at iteration i=6, j=120: 25549.738 / 0.291
# Cost / err at iteration i=6, j=130: 24340.236 / 0.277
# Cost / err at iteration i=6, j=140: 24704.973 / 0.280
# Cost / err at iteration i=7, j=0: 24167.078 / 0.274
# Cost / err at iteration i=7, j=10: 25830.912 / 0.298
# Cost / err at iteration i=7, j=20: 24502.586 / 0.281
# Cost / err at iteration i=7, j=30: 24080.363 / 0.279
# Cost / err at iteration i=7, j=40: 24608.914 / 0.279
# Cost / err at iteration i=7, j=50: 23802.240 / 0.270
# Cost / err at iteration i=7, j=60: 23948.098 / 0.270
# Cost / err at iteration i=7, j=70: 24372.539 / 0.273
# Cost / err at iteration i=7, j=80: 24685.707 / 0.278
# Cost / err at iteration i=7, j=90: 23826.246 / 0.271
# Cost / err at iteration i=7, j=100: 24446.150 / 0.278
# Cost / err at iteration i=7, j=110: 23510.402 / 0.270
# Cost / err at iteration i=7, j=120: 23850.076 / 0.270
# Cost / err at iteration i=7, j=130: 23128.412 / 0.261
# Cost / err at iteration i=7, j=140: 23848.199 / 0.268
# Cost / err at iteration i=8, j=0: 23337.439 / 0.263
# Cost / err at iteration i=8, j=10: 24238.455 / 0.277
# Cost / err at iteration i=8, j=20: 24078.623 / 0.276
# Cost / err at iteration i=8, j=30: 24496.961 / 0.283
# Cost / err at iteration i=8, j=40: 23489.643 / 0.264
# Cost / err at iteration i=8, j=50: 22984.240 / 0.256
# Cost / err at iteration i=8, j=60: 22923.773 / 0.257
# Cost / err at iteration i=8, j=70: 23721.590 / 0.265
# Cost / err at iteration i=8, j=80: 25194.836 / 0.285
# Cost / err at iteration i=8, j=90: 23395.473 / 0.267
# Cost / err at iteration i=8, j=100: 23833.744 / 0.275
# Cost / err at iteration i=8, j=110: 23643.762 / 0.272
# Cost / err at iteration i=8, j=120: 24022.689 / 0.271
# Cost / err at iteration i=8, j=130: 23399.713 / 0.270
# Cost / err at iteration i=8, j=140: 23674.240 / 0.270
# Cost / err at iteration i=9, j=0: 23837.334 / 0.272
# Cost / err at iteration i=9, j=10: 24028.436 / 0.275
# Cost / err at iteration i=9, j=20: 23231.361 / 0.260
# Cost / err at iteration i=9, j=30: 22989.098 / 0.261
# Cost / err at iteration i=9, j=40: 22916.248 / 0.258
# Cost / err at iteration i=9, j=50: 22413.166 / 0.250
# Cost / err at iteration i=9, j=60: 22044.164 / 0.247
# Cost / err at iteration i=9, j=70: 23362.092 / 0.262
# Cost / err at iteration i=9, j=80: 23826.717 / 0.264
# Cost / err at iteration i=9, j=90: 23382.539 / 0.266
# Cost / err at iteration i=9, j=100: 23920.455 / 0.277
# Cost / err at iteration i=9, j=110: 23038.170 / 0.265
# Cost / err at iteration i=9, j=120: 23392.207 / 0.265
# Cost / err at iteration i=9, j=130: 22539.768 / 0.256
# Cost / err at iteration i=9, j=140: 22184.516 / 0.249
# Cost / err at iteration i=10, j=0: 22776.752 / 0.256
# Cost / err at iteration i=10, j=10: 23429.377 / 0.267
# Cost / err at iteration i=10, j=20: 23111.543 / 0.261
# Cost / err at iteration i=10, j=30: 23118.957 / 0.267
# Cost / err at iteration i=10, j=40: 22421.631 / 0.251
# Cost / err at iteration i=10, j=50: 22622.570 / 0.252
# Cost / err at iteration i=10, j=60: 22717.211 / 0.253
# Cost / err at iteration i=10, j=70: 21791.482 / 0.241
# Cost / err at iteration i=10, j=80: 22740.055 / 0.249
# Cost / err at iteration i=10, j=90: 22415.330 / 0.254
# Cost / err at iteration i=10, j=100: 23047.533 / 0.263
# Cost / err at iteration i=10, j=110: 22244.205 / 0.254
# Cost / err at iteration i=10, j=120: 22010.814 / 0.241
# Cost / err at iteration i=10, j=130: 22257.549 / 0.251
# Cost / err at iteration i=10, j=140: 22392.193 / 0.249
# Cost / err at iteration i=11, j=0: 22536.080 / 0.252
# Cost / err at iteration i=11, j=10: 22923.895 / 0.260
# Cost / err at iteration i=11, j=20: 22806.363 / 0.256
# Cost / err at iteration i=11, j=30: 22956.512 / 0.261
# Cost / err at iteration i=11, j=40: 21443.475 / 0.236
# Cost / err at iteration i=11, j=50: 22135.131 / 0.246
# Cost / err at iteration i=11, j=60: 22494.035 / 0.249
# Cost / err at iteration i=11, j=70: 21710.932 / 0.242
# Cost / err at iteration i=11, j=80: 23118.652 / 0.255
# Cost / err at iteration i=11, j=90: 22525.016 / 0.253
# Cost / err at iteration i=11, j=100: 23508.121 / 0.270
# Cost / err at iteration i=11, j=110: 22124.055 / 0.248
# Cost / err at iteration i=11, j=120: 21309.426 / 0.235
# Cost / err at iteration i=11, j=130: 21767.840 / 0.246
# Cost / err at iteration i=11, j=140: 22487.172 / 0.251
# Cost / err at iteration i=12, j=0: 22336.982 / 0.251
# Cost / err at iteration i=12, j=10: 22384.342 / 0.253
# Cost / err at iteration i=12, j=20: 22255.898 / 0.248
# Cost / err at iteration i=12, j=30: 22547.779 / 0.257
# Cost / err at iteration i=12, j=40: 22470.277 / 0.251
# Cost / err at iteration i=12, j=50: 21863.439 / 0.242
# Cost / err at iteration i=12, j=60: 22053.535 / 0.245
# Cost / err at iteration i=12, j=70: 21290.709 / 0.237
# Cost / err at iteration i=12, j=80: 22798.656 / 0.248
# Cost / err at iteration i=12, j=90: 21696.541 / 0.240
# Cost / err at iteration i=12, j=100: 23138.137 / 0.266
# Cost / err at iteration i=12, j=110: 21739.504 / 0.242
# Cost / err at iteration i=12, j=120: 21284.096 / 0.233
# Cost / err at iteration i=12, j=130: 20677.176 / 0.230
# Cost / err at iteration i=12, j=140: 21508.334 / 0.237
# Cost / err at iteration i=13, j=0: 23181.492 / 0.260
# Cost / err at iteration i=13, j=10: 21893.078 / 0.242
# Cost / err at iteration i=13, j=20: 21927.354 / 0.247
# Cost / err at iteration i=13, j=30: 21440.236 / 0.240
# Cost / err at iteration i=13, j=40: 21520.000 / 0.239
# Cost / err at iteration i=13, j=50: 20724.918 / 0.228
# Cost / err at iteration i=13, j=60: 21401.518 / 0.236
# Cost / err at iteration i=13, j=70: 20582.615 / 0.227
# Cost / err at iteration i=13, j=80: 21671.590 / 0.235
# Cost / err at iteration i=13, j=90: 22013.434 / 0.245
# Cost / err at iteration i=13, j=100: 22621.365 / 0.257
# Cost / err at iteration i=13, j=110: 21050.830 / 0.233
# Cost / err at iteration i=13, j=120: 20706.191 / 0.225
# Cost / err at iteration i=13, j=130: 20000.969 / 0.220
# Cost / err at iteration i=13, j=140: 20908.207 / 0.233
# Cost / err at iteration i=14, j=0: 21919.945 / 0.243
# Cost / err at iteration i=14, j=10: 21620.703 / 0.238
# Cost / err at iteration i=14, j=20: 20398.322 / 0.225
# Cost / err at iteration i=14, j=30: 21057.990 / 0.235
# Cost / err at iteration i=14, j=40: 20341.340 / 0.223
# Cost / err at iteration i=14, j=50: 21229.293 / 0.233
# Cost / err at iteration i=14, j=60: 20590.984 / 0.227
# Cost / err at iteration i=14, j=70: 20294.982 / 0.224
# Cost / err at iteration i=14, j=80: 20619.545 / 0.223
# Cost / err at iteration i=14, j=90: 21335.322 / 0.236
# Cost / err at iteration i=14, j=100: 22028.271 / 0.248
# Cost / err at iteration i=14, j=110: 20458.559 / 0.223
# Cost / err at iteration i=14, j=120: 20666.463 / 0.224
# Cost / err at iteration i=14, j=130: 20673.291 / 0.228
# Cost / err at iteration i=14, j=140: 20527.623 / 0.222
# Cost / err at iteration i=15, j=0: 21491.027 / 0.237
# Cost / err at iteration i=15, j=10: 21160.488 / 0.229
# Cost / err at iteration i=15, j=20: 20403.068 / 0.224
# Cost / err at iteration i=15, j=30: 20601.297 / 0.226
# Cost / err at iteration i=15, j=40: 20362.984 / 0.226
# Cost / err at iteration i=15, j=50: 20298.971 / 0.220
# Cost / err at iteration i=15, j=60: 20861.244 / 0.227
# Cost / err at iteration i=15, j=70: 20028.729 / 0.221
# Cost / err at iteration i=15, j=80: 20225.746 / 0.219
# Cost / err at iteration i=15, j=90: 21213.359 / 0.234
# Cost / err at iteration i=15, j=100: 21305.094 / 0.239
# Cost / err at iteration i=15, j=110: 20606.299 / 0.223
# Cost / err at iteration i=15, j=120: 20826.051 / 0.227
# Cost / err at iteration i=15, j=130: 19988.541 / 0.214
# Cost / err at iteration i=15, j=140: 21397.002 / 0.230
# Cost / err at iteration i=16, j=0: 22141.266 / 0.243
# Cost / err at iteration i=16, j=10: 21888.270 / 0.240
# Cost / err at iteration i=16, j=20: 20070.268 / 0.219
# Cost / err at iteration i=16, j=30: 21243.744 / 0.233
# Cost / err at iteration i=16, j=40: 20932.256 / 0.233
# Cost / err at iteration i=16, j=50: 19903.695 / 0.216
# Cost / err at iteration i=16, j=60: 20782.621 / 0.225
# Cost / err at iteration i=16, j=70: 20019.721 / 0.218
# Cost / err at iteration i=16, j=80: 20544.484 / 0.222
# Cost / err at iteration i=16, j=90: 21351.309 / 0.237
# Cost / err at iteration i=16, j=100: 20452.506 / 0.224
# Cost / err at iteration i=16, j=110: 20325.395 / 0.220
# Cost / err at iteration i=16, j=120: 20349.826 / 0.222
# Cost / err at iteration i=16, j=130: 19705.959 / 0.213
# Cost / err at iteration i=16, j=140: 20806.273 / 0.223
# Cost / err at iteration i=17, j=0: 20753.059 / 0.226
# Cost / err at iteration i=17, j=10: 19981.549 / 0.215
# Cost / err at iteration i=17, j=20: 19875.490 / 0.215
# Cost / err at iteration i=17, j=30: 21640.262 / 0.238
# Cost / err at iteration i=17, j=40: 21278.695 / 0.235
# Cost / err at iteration i=17, j=50: 19901.371 / 0.215
# Cost / err at iteration i=17, j=60: 20229.508 / 0.221
# Cost / err at iteration i=17, j=70: 19784.080 / 0.216
# Cost / err at iteration i=17, j=80: 20027.162 / 0.216
# Cost / err at iteration i=17, j=90: 20852.613 / 0.229
# Cost / err at iteration i=17, j=100: 20146.887 / 0.219
# Cost / err at iteration i=17, j=110: 19785.996 / 0.211
# Cost / err at iteration i=17, j=120: 20655.775 / 0.224
# Cost / err at iteration i=17, j=130: 19700.465 / 0.215
# Cost / err at iteration i=17, j=140: 19787.557 / 0.211
# Cost / err at iteration i=18, j=0: 20138.527 / 0.216
# Cost / err at iteration i=18, j=10: 19934.686 / 0.215
# Cost / err at iteration i=18, j=20: 19992.143 / 0.215
# Cost / err at iteration i=18, j=30: 21015.107 / 0.230
# Cost / err at iteration i=18, j=40: 20531.664 / 0.224
# Cost / err at iteration i=18, j=50: 19745.842 / 0.213
# Cost / err at iteration i=18, j=60: 20264.934 / 0.216
# Cost / err at iteration i=18, j=70: 19992.156 / 0.219
# Cost / err at iteration i=18, j=80: 21177.066 / 0.231
# Cost / err at iteration i=18, j=90: 20085.469 / 0.217
# Cost / err at iteration i=18, j=100: 20271.441 / 0.220
# Cost / err at iteration i=18, j=110: 20010.422 / 0.212
# Cost / err at iteration i=18, j=120: 20353.377 / 0.216
# Cost / err at iteration i=18, j=130: 19716.066 / 0.212
# Cost / err at iteration i=18, j=140: 21462.172 / 0.226
# Cost / err at iteration i=19, j=0: 19995.762 / 0.214
# Cost / err at iteration i=19, j=10: 19660.113 / 0.209
# Cost / err at iteration i=19, j=20: 19380.305 / 0.211
# Cost / err at iteration i=19, j=30: 19608.680 / 0.214
# Cost / err at iteration i=19, j=40: 20567.195 / 0.224
# Cost / err at iteration i=19, j=50: 19803.332 / 0.210
# Cost / err at iteration i=19, j=60: 19852.562 / 0.213
# Cost / err at iteration i=19, j=70: 19763.959 / 0.210
# Cost / err at iteration i=19, j=80: 20601.400 / 0.223
# Cost / err at iteration i=19, j=90: 19941.113 / 0.217
# Cost / err at iteration i=19, j=100: 19446.797 / 0.211
# Cost / err at iteration i=19, j=110: 19853.555 / 0.209
# Cost / err at iteration i=19, j=120: 21081.072 / 0.226
# Cost / err at iteration i=19, j=130: 20085.953 / 0.217
# Cost / err at iteration i=19, j=140: 19631.377 / 0.205
# Elapsed time: 0:02:17.141677
